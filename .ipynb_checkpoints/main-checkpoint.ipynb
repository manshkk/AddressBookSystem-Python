# %%
import importlib
import models.contact
import models.address_book

importlib.reload(models.contact)
importlib.reload(models.address_book)

from models.contact import Contact
from models.address_book import AddressBook

book = AddressBook("Friends")

book.add_contact(Contact(
    "Rahul",
    "Sharma",
    "MG Road",
    "Bangalore",
    "Karnataka",
    "560001",
    "9876543210",
    "rahul@gmail.com"
))

book.add_contact(Contact(
    "Amit",
    "Kumar",
    "Sector 10",
    "Delhi",
    "Delhi",
    "110001",
    "9999999999",
    "amit@gmail.com"
))

book.add_contact(Contact(
    "Priya",
    "Singh",
    "Indiranagar",
    "Bangalore",
    "Karnataka",
    "560038",
    "8888888888",
    "priya@gmail.com"
))

book.search_by_city("Bangalore")

book.search_by_state("Delhi")
# Out:
# Traceback (most recent call last):
#
#   File D:\java\download\anaconda\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[22], line 5
#     importlib.reload(models.contact)
#
#   File D:\java\download\anaconda\Lib\importlib\__init__.py:129 in reload
#     _bootstrap._exec(spec, module)
#
#   File <frozen importlib._bootstrap>:866 in _exec
#
#   File <frozen importlib._bootstrap_external>:1023 in exec_module
#
#   File <frozen importlib._bootstrap_external>:1161 in get_code
#
#   File <frozen importlib._bootstrap_external>:1091 in source_to_code
#
#   File <frozen importlib._bootstrap>:488 in _call_with_frames_removed
#
#   File ~\AddressBookSystem\models\contact.py:100
#     )     self.email = email
#           ^
# SyntaxError: invalid syntax

# %%
print("Total Contacts :", book.total_contacts())
# Out:
# Total Contacts : 1
