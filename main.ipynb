# %%
import importlib
import models.address_book

importlib.reload(models.address_book)

from models.contact import Contact
from models.address_book import AddressBook

book = AddressBook("Friends")

contact = Contact(
    "Rahul",
    "Sharma",
    "MG Road",
    "Bangalore",
    "Karnataka",
    "560001",
    "9876543210",
    "rahul@gmail.com"
)

book.add_contact(contact)

book.edit_contact(
    "Rahul",
    "Sharma",
    city="Mysore",
    phone="9999999999"
)

book.display_contacts()
# Out:
# Contact Added Successfully: Rahul Sharma
#
#
# Contact Updated Successfully: Rahul Sharma
#
#
# Address Book : Friends
# ==================================================
#
# Contact 1
# <models.contact.Contact object at 0x0000019CDFDA6210>
# --------------------------------------------------

# %%
print("Total Contacts :", book.total_contacts())
# Out:
# Total Contacts : 2
