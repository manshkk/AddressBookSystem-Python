# %%
from models.contact import Contact
from models.address_book import AddressBook

book = AddressBook("Friends")

c1 = Contact(
    "Rahul",
    "Sharma",
    "MG Road",
    "Bangalore",
    "Karnataka",
    "560001",
    "9876543210",
    "rahul@gmail.com"
)

c2 = Contact(
    "Rahul",
    "Sharma",
    "Another Address",
    "Delhi",
    "Delhi",
    "110001",
    "9999999999",
    "rahul2@gmail.com"
)

book.add_contact(c1)
book.add_contact(c2)

book.display_contacts()

print("Total Contacts:", book.total_contacts())
# Out:
# Address Book : Friends
# --------------------------------------------------
#
# Contact 1
# <models.contact.Contact object at 0x0000019CDF77B310>
# --------------------------------------------------
#
# Contact 2
# <models.contact.Contact object at 0x0000019CDF77AF90>
# --------------------------------------------------
# Total Contacts: 2

# %%
print("Total Contacts :", book.total_contacts())
# Out:
# Total Contacts : 2
