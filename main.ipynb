# %%
contact = Contact(
    "Rahul",
    "Sharma",
    "MG Road",
    "Bangalore",
    "Karnataka",
    "560001",
    "9876543210",
    "rahul@gmail.com"
)

print(contact)

print("--------------------")

print(repr(contact))
# Out:
# ...
# --------------------
# ...
